# %% [markdown]
# <a href="https://colab.research.google.com/github/Reth202/Tesis_Analisis_Del_Sentimiento/blob/main/Entregable_2_Proyecto_final_19_Junio_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install streamlit
# %pip install streamlit-lottie
# %pip install gradio
# %pip install ffmpeg
# %pip install -U openai-whisper
# %pip install numpy pandas scikit-learn tensorflow
# %pip install librosa
# %pip install opensmile
# %pip install soundfile
# %pip install resampy
# %pip install transformers
# %pip install scipy
# %pip install oracledb
# Out:
# Requirement already satisfied: streamlit in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (1.36.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (1.26.2)
# Requirement already satisfied: packaging<25,>=20 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit-lottie in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (0.0.5)
# Requirement already satisfied: streamlit>=0.63 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit-lottie) (1.36.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (1.26.2)
# Requirement already satisfied: packaging<25,>=20 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (10.3.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (4.9.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (6.3.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from streamlit>=0.63->streamlit-lottie) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (4.19.2)
# Requirement already satisfied: toolz in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (0.12.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from click<9,>=7.0->streamlit>=0.63->streamlit-lottie) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-lottie) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-lottie) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-lottie) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=0.63->streamlit-lottie) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit-lottie) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich<14,>=10.14.0->streamlit>=0.63->streamlit-lottie) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-lottie) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.63->streamlit-lottie) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=0.63->streamlit-lottie) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gradio in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (4.36.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.111.0)
# Requirement already satisfied: ffmpy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==1.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (1.0.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.23.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (3.9.0)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (1.26.2)
# Requirement already satisfied: orjson~=3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (3.10.5)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (2.1.4)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (2.7.4)
# Requirement already satisfied: pydub in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.4.10)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (4.9.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (2.1.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio) (0.30.1)
# Requirement already satisfied: fsspec in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio-client==1.0.1->gradio) (2024.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from gradio-client==1.0.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from httpx>=0.24.1->gradio) (4.2.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.15.4)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from matplotlib~=3.0->gradio) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pydantic>=2.0->gradio) (2.18.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from fastapi->gradio) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from fastapi->gradio) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from fastapi->gradio) (2.2.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.6)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi->gradio) (0.22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ffmpeg in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (1.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai-whisper in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (20231117)
# Requirement already satisfied: numba in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from openai-whisper) (1.26.2)
# Requirement already satisfied: torch in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from openai-whisper) (2.3.1)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from openai-whisper) (10.3.0)
# Requirement already satisfied: tiktoken in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from openai-whisper) (0.7.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tiktoken->openai-whisper) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (4.9.0)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (1.12.1)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from torch->openai-whisper) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tqdm->openai-whisper) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->openai-whisper) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->openai-whisper) (2021.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from jinja2->torch->openai-whisper) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from sympy->torch->openai-whisper) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (1.26.2)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (2.1.4)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (1.2.2)
# Requirement already satisfied: tensorflow in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (2.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: librosa in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (1.26.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opensmile in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (2.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: audobject>=0.6.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from opensmile) (0.7.11)
# Requirement already satisfied: audinterface>=0.7.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from opensmile) (1.2.1)
# Requirement already satisfied: audeer>=1.18.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audinterface>=0.7.0->opensmile) (2.0.0)
# Requirement already satisfied: audformat<2.0.0,>=1.0.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audinterface>=0.7.0->opensmile) (1.1.4)
# Requirement already satisfied: audiofile>=1.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audinterface>=0.7.0->opensmile) (1.4.0)
# Requirement already satisfied: audmath>=1.3.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audinterface>=0.7.0->opensmile) (1.4.1)
# Requirement already satisfied: audresample<2.0.0,>=1.1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audinterface>=0.7.0->opensmile) (1.3.3)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audobject>=0.6.1->opensmile) (7.2.0)
# Requirement already satisfied: oyaml in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audobject>=0.6.1->opensmile) (1.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audobject>=0.6.1->opensmile) (23.2)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audeer>=1.18.0->audinterface>=0.7.0->opensmile) (4.66.4)
# Requirement already satisfied: iso-639 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (0.4.5)
# Requirement already satisfied: iso3166 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.1.1)
# Requirement already satisfied: pyyaml>=5.4.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.1)
# Requirement already satisfied: pandas>=1.4.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.1.4)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.26.2)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2023.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tqdm->audeer>=1.18.0->audinterface>=0.7.0->opensmile) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.1->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: soundfile in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: resampy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (0.4.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from resampy) (1.26.2)
# Requirement already satisfied: numba>=0.53 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from resampy) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from numba>=0.53->resampy) (0.43.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (4.41.2)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.9.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from requests->transformers) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from scipy) (1.26.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: oracledb in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (2.2.1)
# Requirement already satisfied: cryptography>=3.2.1 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from oracledb) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from cryptography>=3.2.1->oracledb) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\envs\ambientemaestria\lib\site-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import pandas as pd
import numpy as np
import subprocess

import librosa
from librosa import display

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig, pipeline
from scipy.special import softmax

import gradio as gr
import whisper
from whisper import load_model
import shutil

from datetime import datetime
import oracledb
from pydub import AudioSegment
